# %% [markdown]
# # Files, exceptional handling, logging and memory management Questions
#
# # Theoratical Question
#
# Que.1)What is the difference between interpreted and compiled languages?
# Ans:- i)Interpreted: Executes code line-by-line (e.g., Python).
# ii)Compiled: Translates entire code to machine language before execution (e.g., C++).
#
# -------------------------------------------------------------------------------------------------------------------------------------------------------
# Que.2)What is exception handling in Python?
# Ans:- Mechanism to catch and manage runtime errors using try, except, finally, and else.
#
# -------------------------------------------------------------------------------------------------------------------------------------------------------
# Que.3)What is the purpose of the finally block in exception handling?
# Ans:- Executes cleanup code regardless of whether an exception occurred.
#
# -------------------------------------------------------------------------------------------------------------------------------------------------------
# Que.4)What is logging in Python?
# Ans:-- Records events during program execution using the logging module for debugging and monitoring.
#
# -------------------------------------------------------------------------------------------------------------------------------------------------------
# Que.5)What is the significance of the __del__ method in Python?
# Ans:-Destructor method called when an object is about to be destroyed, used for cleanup.
#
# -------------------------------------------------------------------------------------------------------------------------------------------------------
# Que.6)What is the difference between import and from ... import in Python?
# Ans:-i) import module: Access via module.function()
# ii) from module import function: Direct access via function()
#
# -------------------------------------------------------------------------------------------------------------------------------------------------------
# Que.7)How can you handle multiple exceptions in Python?
# Ans:- Use multiple except blocks or a tuple:
# Example:except (TypeError, ValueError) as e:
#
# -------------------------------------------------------------------------------------------------------------------------------------------------------
# Que.8)What is the purpose of the with statement when handling files in Python?
# Ans:-Ensures proper acquisition and release of resources (auto-closes file).
#
# -------------------------------------------------------------------------------------------------------------------------------------------------------
# Que.9)What is the difference between multithreading and multiprocessing?
# Ans:- i)Multithreading: Multiple threads in one process (shared memory).
# ii) Multiprocessing: Multiple processes (separate memory, better for CPU-bound tasks).
#
# -------------------------------------------------------------------------------------------------------------------------------------------------------
# Que.10)What are the advantages of using logging in a program?
# Ans:-Tracks errors, improves debugging, maintains audit trails, and supports configurable output levels.
#
# -------------------------------------------------------------------------------------------------------------------------------------------------------
# Que.11)What is memory management in Python?
# Ans:- Managed via reference counting and garbage collection (GC module).
#
# -------------------------------------------------------------------------------------------------------------------------------------------------------
# Que.12)What are the basic steps involved in exception handling in Python?
# Ans:- - try: Code that may raise an error
# - except: Handles the error
# - else: Executes if no error
# - finally: Executes always
#
# -------------------------------------------------------------------------------------------------------------------------------------------------------
# Que.13)Why is memory management important in Python?
# Ans:- Prevents memory leaks, optimizes performance, and ensures efficient resource use.
#
# -------------------------------------------------------------------------------------------------------------------------------------------------------
# Que.14)What is the role of try and except in exception handling?
# Ans:- Role of try and except
# i) try: Wraps risky code
# ii) except: Catches and handles exceptions
#
# -------------------------------------------------------------------------------------------------------------------------------------------------------
# Que.15)How does Python's garbage collection system work?
# Ans:-- Automatically frees memory by deleting objects with zero references using reference counting and cyclic GC.
#
# -------------------------------------------------------------------------------------------------------------------------------------------------------
# Que.16)What is the purpose of the else block in exception handling?
# Ans:- Purpose of else block is executes only if no exception occurs in the try block.File Handling & Logging
#
# -------------------------------------------------------------------------------------------------------------------------------------------------------
# Que.17)What are the common logging levels in Python?
# Ans:- Common logging levels are = DEBUG, INFO, WARNING, ERROR and CRITICAL.
#
# -------------------------------------------------------------------------------------------------------------------------------------------------------
# Que.18)What is the difference between os.fork() and multiprocessing in Python?
# Ans:- i) os.fork(): Unix-only, low-level process creation
# ii) multiprocessing: Cross-platform, high-level API for parallelism
#
# -------------------------------------------------------------------------------------------------------------------------------------------------------
# Que.19)What is the importance of closing a file in Python?
# Ans:- Frees system resources, ensures data is written, avoids file corruption.
#
# -------------------------------------------------------------------------------------------------------------------------------------------------------
# Que.20)What is the difference between file.read() and file.readline() in Python?
# Ans:- file.read() vs file.readline()
# i) read(): Reads entire file
# ii) readline(): Reads one line at a time
#
# -------------------------------------------------------------------------------------------------------------------------------------------------------
# Que.21)What is the logging module in Python used for?
# Ans:- Provides flexible logging system for tracking events and debugging.
#
# -------------------------------------------------------------------------------------------------------------------------------------------------------
# Que.22)What is the os module in Python used for in file handling?
# Ans:-Interacts with the operating system: file paths, directory management, environment variables.
#
# -------------------------------------------------------------------------------------------------------------------------------------------------------
# Que.23)What are the challenges associated with memory management in Python?
# Ans:-Challenges in memory management in python is Circular references, memory leaks, manual resource cleanup, and performance tuning.
#
# -------------------------------------------------------------------------------------------------------------------------------------------------------
# Que.24)How do you raise an exception manually in Python?
# Ans:- Use raise keyword:
# raise ValueError("Invalid input")
#
# -------------------------------------------------------------------------------------------------------------------------------------------------------
# Que.25)Why is it important to use multithreading in certain applications??
# Ans:- Importance of multithreading is improves responsiveness, handles I/O-bound tasks efficiently, enables concurrent execution.

# %%
#Prcatical questions:-

#Que.1)How can you open a file for writing in Python and write a string to it?
#Ans:-
with open("example.txt", "w") as file:
    file.write("Hello, This is a test string.")

# %%
#Que.2)Write a Python program to read the contents of a file and print each line
#Ans:-
with open("example.txt", "r") as file:
    contents = file.read()
    print(contents)
# Out:
# Hello, This is a test string.

# %%
#Que.3)How would you handle a case where the file doesn't exist while trying to open it for reading?
#Ans:-
try:
    with open("example1.txt", "r") as file:
        print(file.read())
except FileNotFoundError:
    print("File not found. Please check the filename.")
except PermissionError:
    print("You don't have permission to read this file.")
# Out:
# File not found. Please check the filename.

# %%
#Que.4)Write a Python script that reads from one file and writes its content to another file.
#Ans:- 
# Open the source file in read mode
with open("example.txt", "r") as src: #example.txt is a source file
    # Read all contents
    content = src.read()

# Open the destination file in write mode
with open("destination.txt", "w") as dest:
    # Write the contents into the destination file
    dest.write(content)

print("File copied successfully!")
# Out:
# File copied successfully!

# %%
#Que.5)How would you catch and handle division by zero error in Python?
#Ans:-
try:
    # operation: division
    result = 10 / 0
    print("Result:", result)
except ZeroDivisionError:
    print("Error: Division by zero is not allowed.")
# Out:
# Error: Division by zero is not allowed.

# %%
#Que.6)Write a Python program that logs an error message to a log file when a division by zero exception occurs
#Ans:-
import logging
# Configure logging: log messages will be written to 'app.log'
logging.basicConfig(filename="app.log", level=logging.ERROR, format="%(asctime)s - %(levelname)s - %(message)s")
try:
    # operation: division
    result = 10 / 0
    print("Result:", result)
except ZeroDivisionError as e:
    logging.error("Division by zero error occurred: %s", e)
    print("Error handled. Check 'app.log' for details.")
# Out:
# Error handled. Check 'app.log' for details.

# %%
#Que.7)How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module?
#Ans:-
import logging

# Configure logging
logging.basicConfig(filename="app.log", level=logging.DEBUG,format="%(asctime)s - %(levelname)s - %(message)s")

# Log messages at different levels
logging.info("This is an INFO message: program started successfully.")
logging.warning("This is a WARNING message: disk space is running low.")
logging.error("This is an ERROR message: unable to connect to database.")

# %%
#Que.8)Write a program to handle a file opening error using exception handling
#Ans:-
try:
    # Attempt to open a file that may not exist
    with open("myfile.txt", "r") as file:
        content = file.read()
        print(content)

except FileNotFoundError:
    print("Error: The file 'myfile.txt' was not found.")

except PermissionError:
    print("Error: You don't have permission to open 'myfile.txt'.")

except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Error: The file 'myfile.txt' was not found.

# %%
#Que.9)How can you read a file line by line and store its content in a list in Python?
#Ans:-
with open("example.txt", "r") as file:
    lines = file.readlines()
lines = [line.strip() for line in lines]

print(lines)
# Out:
# ['Hello, This is a test string.']

# %%
#Que.10)How can you append data to an existing file in Python?
#Ans:-
with open("example.txt", "a") as file:
    # Write new data at the end of the file
    file.write("\nThis is new appended data.")

# Now read the file and print its contents
with open("example.txt", "r") as file:
    content = file.read()
    print(content)
# Out:
# Hello, This is a test string.
# This is new appended data.
# This is new appended data.

# %%
#Que.11)Write a Python program that uses a try-except block to handle an error when attempting to access a dictionary key that doesn't exist.
#Ans:-
student = {
    "name": "Shravani",
    "age": 24,
    "course": "Python Programming"
}

try:
    # Attempt to access a key that may not exist
    grade = student["grade"]
    print("Grade:", grade)

except KeyError as e:
    # Handle the missing key error
    print(f"Error: The key '{e.args[0]}' does not exist in the dictionary.")
# Out:
# Error: The key 'grade' does not exist in the dictionary.

# %%
#Que.12)Write a program that demonstrates using multiple except blocks to handle different types of exceptions.
#Ans:-
try:
    # Risky operations
    num = int(input("Enter a number: "))   # May raise ValueError
    result = 10 / num                      # May raise ZeroDivisionError
    print("Result:", result)

    # Accessing a dictionary key that may not exist
    student = {"name": "Shrushti", "course": "Python"}
    print("Grade:", student["grade"])      # May raise KeyError

except ValueError:
    # Handles invalid input conversion
    print("Error: Please enter a valid integer.")

except ZeroDivisionError:
    # Handles division by zero
    print("Error: Division by zero is not allowed.")

except KeyError as e:
    # Handles missing dictionary key
    print(f"Error: The key '{e.args[0]}' does not exist in the dictionary.")

except Exception as e:
    # Handles any other unexpected exceptions
    print(f"An unexpected error occurred: {e}")
# Out:
# Enter a number:  1
# Result: 10.0
# Error: The key 'grade' does not exist in the dictionary.

# %%
#Que.13)How would you check if a file exists before attempting to read it in Python?
#Ans;-
import os
filename = "example.txt"

if os.path.exists(filename):
    with open(filename, "r") as file:
        content = file.read()
        print(content)
else:
    print(f"Error: The file '{filename}' does not exist.")
# Out:
# Hello, This is a test string.
# This is new appended data.
# This is new appended data.

# %%
#Que.14)Write a program that uses the logging module to log both informational and error messages
#Ans:-
import logging

# Configure logging
logging.basicConfig(level=logging.DEBUG,format="%(asctime)s - %(levelname)s - %(message)s",
    handlers=[
        logging.FileHandler("app.log"), 
        logging.StreamHandler()   
    ]
)

# Log an informational message
logging.info("Program started successfully.")

try:
    # operation: division
    result = 10 / 0
    logging.info(f"Result: {result}")
except ZeroDivisionError as e:
    # Log an error message
    logging.error("Division by zero error occurred: %s", e)

logging.info("Program finished execution.")

# %%
#Que.15)Write a Python program that prints the content of a file and handles the case when the file is empty
#Ans:-
import os

filename = "example.txt"

try:
    # Check if file exists
    if os.path.exists(filename):
        with open(filename, "r") as file:
            content = file.read()
            
            if content.strip():   # Check if file has non-empty content
                print("File content:\n")
                print(content)
            else:
                print(f"The file '{filename}' is empty.")
    else:
        print(f"Error: The file '{filename}' does not exist.")

except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# File content:
#
# Hello, This is a test string.
# This is new appended data.
# This is new appended data.

# %%
#Que.16)Demonstrate how to use memory profiling to check the memory usage of a small program.
#Ans:-
import psutil, os

def memory_usage():
    process = psutil.Process(os.getpid())
    return process.memory_info().rss / (1024 * 1024)  # in MB

print("Memory before:", memory_usage(), "MB")
data = [i for i in range(1000000)]
print("Memory after:", memory_usage(), "MB")
# Out:
# Memory before: 85.75390625 MB
# Memory after: 125.765625 MB

# %%
#Que.17)Write a Python program to create and write a list of numbers to a file, one number per line.
#Ans:-
numbers = [1, 2, 3, 4, 5, 10, 20, 30]

with open("numbers.txt", "w") as file:
    for num in numbers:
        file.write(str(num) + "\n")   # Write each number followed by a newline

print("Numbers have been written to 'numbers.txt' successfully!")
# Out:
# Numbers have been written to 'numbers.txt' successfully!

# %%
#Que.18)How would you implement a basic logging setup that logs to a file with rotation after 1MB
#Ans:-
import logging
from logging.handlers import RotatingFileHandler

# Configure Rotating File Handler
log_handler = RotatingFileHandler(
    "app.log",        # Log file name
    maxBytes=1_000_000,  # Rotate after 1MB
    backupCount=3        # Keep up to 3 backup files
)

# Set logging format
formatter = logging.Formatter("%(asctime)s - %(levelname)s - %(message)s")
log_handler.setFormatter(formatter)

# Create logger
logger = logging.getLogger("MyLogger")
logger.setLevel(logging.DEBUG)   # Capture all levels
logger.addHandler(log_handler)

# Example log messages
logger.info("Program started successfully.")
logger.warning("This is a warning message.")
logger.error("An error occurred in the program.")

# %%
#Que.19)Write a program that handles both IndexError and KeyError using a try-except block
#Ans:-
numbers = [10, 20, 30]
student = {"name": "Shravani", "course": "Python"}

try:
    # Attempt to access an invalid list index
    print("Number at index 5:", numbers[5])

    # Attempt to access a missing dictionary key
    print("Grade:", student["grade"])

except IndexError as e:
    # Handle invalid list index
    print(f"IndexError: {e}. The index you tried to access is out of range.")

except KeyError as e:
    # Handle missing dictionary key
    print(f"KeyError: The key '{e.args[0]}' does not exist in the dictionary.")

except Exception as e:
    # Catch any other unexpected exceptions
    print(f"Unexpected error: {e}")
# Out:
# IndexError: list index out of range. The index you tried to access is out of range.

# %%
#Que.20)How would you open a file and read its contents using a context manager in Python
#Ans:-
with open("example.txt", "r") as file:
    for line in file:
        print(line.strip())
# Out:
# Hello, This is a test string.
# This is new appended data.
# This is new appended data.

# %%
#Que.21)Write a Python program that reads a file and prints the number of occurrences of a specific word
#Ans:-
def count_word_occurrences(filename, word):
    try:
        with open(filename, "r") as file:
            content = file.read().lower()   # Read file and convert to lowercase
            words = content.split()         # Split into individual words
            count = words.count(word.lower())
            print(f"The word '{word}' occurs {count} times in '{filename}'.")
    except FileNotFoundError:
        print(f"Error: The file '{filename}' does not exist.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

count_word_occurrences("example.txt", "python")
# Out:
# The word 'python' occurs 0 times in 'example.txt'.

# %%
#Que.22)How can you check if a file is empty before attempting to read its contents
#Ans:-
import os

filename = "example.txt"

if os.path.exists(filename):
    if os.path.getsize(filename) == 0:
        print(f"The file '{filename}' is empty.")
    else:
        with open(filename, "r") as file:
            content = file.read()
            print("File content:\n", content)
else:
    print(f"Error: The file '{filename}' does not exist.")
# Out:
# File content:
#  Hello, This is a test string.
# This is new appended data.
# This is new appended data.

# %%
#Que.23)Write a Python program that writes to a log file when an error occurs during file handling.
#Ans:-
import logging

# Configure logging to write to a file
logging.basicConfig(
    filename="file_errors.log",       # Log file name
    level=logging.ERROR,              # Only log errors and above
    format="%(asctime)s - %(levelname)s - %(message)s"
)

filename = "example.txt"

try:
    # Attempt to open and read a file
    with open(filename, "r") as file:
        content = file.read()
        print("File content:\n", content)

except FileNotFoundError as e:
    print(f"Error: The file '{filename}' does not exist.")
    logging.error("FileNotFoundError: %s", e)

except PermissionError as e:
    print(f"Error: You don't have permission to open '{filename}'.")
    logging.error("PermissionError: %s", e)

except Exception as e:
    print(f"An unexpected error occurred: {e}")
    logging.error("Unexpected error: %s", e)
# Out:
# File content:
#  Hello, This is a test string.
# This is new appended data.
# This is new appended data.
