# %% [markdown]
# # Python OOPs Questions
#
# # Theoratical questions
#
# Que1)What is Object-Oriented Programming (OOP)?
# Ans:- OOPS is a paradigm based on objects that encapsulate data and behavior. It promotes modularity, reusability, and abstraction.
#
# -------------------------------------------------------------------------------------------------------------------------------------------------------
# Que2)What is a class in OOP?
# Ans:- A blueprint for creating objects. It defines attributes and methods that its instances will have.
#
# -------------------------------------------------------------------------------------------------------------------------------------------------------
# Que3)What is an object in OOP?
# Ans:- Object is an instance of a class. It holds actual data and can use the class-defined methods
#
# -------------------------------------------------------------------------------------------------------------------------------------------------------
# Que4)What is the difference between abstraction and encapsulation?
# Ans:- i) Abstraction: Hides implementation details, showing only relevant features.
# ii) Encapsulation: Bundles data and methods, restricting direct access to internal states.
#
# -------------------------------------------------------------------------------------------------------------------------------------------------------
# Que5)What are dunder methods in Python?
# Ans:- Dunder Special methods with double underscores (e.g., __init__, __str__) that customize object behavior.
#
# -------------------------------------------------------------------------------------------------------------------------------------------------------
# Que6)Explain the concept of inheritance in OOP.
# Ans:- Inheritance allows a class (child) to inherit attributes and methods from another class (parent), promoting code reuse.
#
# -------------------------------------------------------------------------------------------------------------------------------------------------------
# Que7)What is polymorphism in OOP?
# Ans:- Polymorphism enables objects of different classes to be treated as instances of the same class through shared interfaces.
#
# -------------------------------------------------------------------------------------------------------------------------------------------------------
# Que8)How is encapsulation achieved in Python?
# Ans:- Encapsulation achieved using private (_var, __var) and public attributes, and getter/setter methods.
#
# -------------------------------------------------------------------------------------------------------------------------------------------------------
# Que9)What is a constructor in Python?
# Ans:- constructor in Python - The __init__ method initializes object attributes when an object is created.
#
# -------------------------------------------------------------------------------------------------------------------------------------------------------
# Que10)What are class and static methods in Python?
# Ans:- i) Class Method: Uses @classmethod, takes cls as the first argument.
# ii) Static Method: Uses @staticmethod, doesn’t take self or cls.
#
# -------------------------------------------------------------------------------------------------------------------------------------------------------
# Que11)What is method overloading in Python?
# Ans:- Method overloading not natively supported in Python. Achieved via default arguments or variable-length arguments.
#
# -------------------------------------------------------------------------------------------------------------------------------------------------------
# Que12)What is method overriding in OOP?
# Ans:- Method overriding in OOP is a subclass redefines a method from its parent class to change or extend its behavior.
#
# -------------------------------------------------------------------------------------------------------------------------------------------------------
# Que13)What is a property decorator in Python?
# Ans:- Property decorator, @property allows a method to be accessed like an attribute, enabling controlled access.
#
# -------------------------------------------------------------------------------------------------------------------------------------------------------
# Que14)Why is polymorphism important in OOP?
# Ans:- Polymorphism is importance in OOPs as it promotes flexibility and scalability by allowing interchangeable object use.
#
# -------------------------------------------------------------------------------------------------------------------------------------------------------
# Que15)What is an abstract class in Python?
# Ans:- It defined using abc module. Cannot be instantiated and may contain abstract methods.
#
# -------------------------------------------------------------------------------------------------------------------------------------------------------
# Que16)What are the advantages of OOP?
# Ans:- Advantages of OOP are as follows
# i) Modularity
# ii) Reusability
# iii) Scalability
# iv) Easier maintenance
#
# -------------------------------------------------------------------------------------------------------------------------------------------------------
# Que17)What is the difference between a class variable and an instance variable?
# Ans:- i)Class Variable: Shared across all instances.
# ii) Instance Variable: Unique to each object.
#
# -------------------------------------------------------------------------------------------------------------------------------------------------------
# Que18)What is multiple inheritance in Python?
# Ans:-A class inherits from more than one parent class. Python supports it via MRO (Method Resolution Order).
#
# -------------------------------------------------------------------------------------------------------------------------------------------------------
# Que19)Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python
# Ans:- i) __str__: User-friendly string representation.
# ii) __repr__: Developer-friendly, often used for debugging.
#
# -------------------------------------------------------------------------------------------------------------------------------------------------------
# Que20)What is the significance of the ‘super()’ function in Python?
# Ans:- super() Function calls methods from the parent class, useful in inheritance and method overriding.
#
# -------------------------------------------------------------------------------------------------------------------------------------------------------
# Que21)What is the significance of the __del__ method in Python?
# Ans:- __del__ Method is a destructor method called when an object is about to be destroyed. Used for cleanup.
#
# -------------------------------------------------------------------------------------------------------------------------------------------------------
# Que22)What is the difference between @staticmethod and @classmethod in Python?
# Ans:- i) @staticmethod: No access to class or instance.
# ii) @classmethod: Access to class (cls), but not instance.
#
# -------------------------------------------------------------------------------------------------------------------------------------------------------
# Que23)How does polymorphism work in Python with inheritance?
# Ans:- Polymorphism with Inheritance: Subclasses override parent methods, allowing dynamic method resolution.
#
# -------------------------------------------------------------------------------------------------------------------------------------------------------
# Que24)What is method chaining in Python OOP?
# Ans:- Method Chaining in Python OOP is Calling multiple methods on the same object in a single line (e.g., obj.method1().method2()).
#
# -------------------------------------------------------------------------------------------------------------------------------------------------------
# Que25)What is the purpose of the __call__ method in Python?
# Ans:- __call__ Method, it makes an object callable like a function. Useful for function-like behavior in classes.

# %%
#Practical questions

#Que.1) Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog that overrides the speak() method to print "Bark!".
#Ans:- 
# Parent class
class Animal:
    def speak(self):
        print("This animal makes a sound.")

# Child class
class Dog(Animal):
    def speak(self):
        print("Bark!")

generic_animal = Animal()
generic_animal.speak()   # Output: This animal makes a sound.

dog = Dog()
dog.speak()
# Out:
# This animal makes a sound.
# Bark!

# %%
#Que2) Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle from it and implement the area() method in both.
#Ans:-
from abc import ABC, abstractmethod
import math

# Abstract class
class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

# Derived class: Circle
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * (self.radius ** 2)

# Derived class: Rectangle
class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

# Example usage
circle = Circle(5)
print("Circle area:", circle.area())  

rectangle = Rectangle(4, 6)
print("Rectangle area:", rectangle.area())
# Out:
# Circle area: 78.53981633974483
# Rectangle area: 24

# %%
#Que3) Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car and further derive a class ElectricCar that adds a battery attribute.
#Ans:-
# Base class
class Vehicle:
    def __init__(self, vehicle_type):
        self.type = vehicle_type

    def show_type(self):
        print(f"Vehicle type: {self.type}")

# Derived class from Vehicle
class Car(Vehicle):
    def __init__(self, vehicle_type, brand):
        super().__init__(vehicle_type)
        self.brand = brand

    def show_details(self):
        print(f"Car brand: {self.brand}, Type: {self.type}")

# Further derived class from Car
class ElectricCar(Car):
    def __init__(self, vehicle_type, brand, battery_capacity):
        super().__init__(vehicle_type, brand)
        self.battery = battery_capacity

    def show_info(self):
        print(f"Electric Car - Brand: {self.brand}, Type: {self.type}, Battery: {self.battery} kWh")

vehicle = Vehicle("Four-wheeler")
vehicle.show_type()   

car = Car("Four-wheeler", "Toyota")
car.show_details()  

electric_car = ElectricCar("Four-wheeler", "Tesla", 85)
electric_car.show_info()
# Out:
# Vehicle type: Four-wheeler
# Car brand: Toyota, Type: Four-wheeler
# Electric Car - Brand: Tesla, Type: Four-wheeler, Battery: 85 kWh

# %%
#Que4) Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes Sparrow and Penguin that override the fly() method.
#Ans:-
# Base class
class Bird:
    def fly(self):
        print("This bird can fly in some way.")

# Derived class: Sparrow
class Sparrow(Bird):
    def fly(self):
        print("Sparrow flies high and fast!")

# Derived class: Penguin
class Penguin(Bird):
    def fly(self):
        print("Penguins cannot fly, they swim instead!")


def demonstrate_flying(bird):
    bird.fly()   # Polymorphism: calls the appropriate method depending on the object

# Create objects
sparrow = Sparrow()
penguin = Penguin()

demonstrate_flying(sparrow)  
demonstrate_flying(penguin)
# Out:
# Sparrow flies high and fast!
# Penguins cannot fly, they swim instead!

# %%
#Que5) Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes balance and methods to deposit, withdraw, and check balance.
#Ans:-
class BankAccount:
    def __init__(self, initial_balance=0):
        # Private attribute
        self.__balance = initial_balance

    # Method to deposit money
    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"Deposited: {amount}")
        else:
            print("Deposit amount must be positive.")

    # Method to withdraw money
    def withdraw(self, amount):
        if 0 < amount <= self.__balance:
            self.__balance -= amount
            print(f"Withdrew: {amount}")
        else:
            print("Insufficient balance or invalid amount.")

    # Method to check balance
    def check_balance(self):
        print(f"Current Balance: {self.__balance}")


account = BankAccount(100)  
account.check_balance()      

account.deposit(50)        
account.check_balance()     

account.withdraw(70)         
account.check_balance()      

account.withdraw(200)
# Out:
# Current Balance: 100
# Deposited: 50
# Current Balance: 150
# Withdrew: 70
# Current Balance: 80
# Insufficient balance or invalid amount.

# %%
#Que6) Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar and Piano that implement their own version of play().
#Ans:-
# Base class
class Instrument:
    def play(self):
        print("This instrument makes a sound.")

# Derived class: Guitar
class Guitar(Instrument):
    def play(self):
        print("Strumming the guitar...")

# Derived class: Piano
class Piano(Instrument):
    def play(self):
        print("Playing the piano... ")

# Function to demonstrate polymorphism
def perform(instrument):
    instrument.play()   # Calls the appropriate play() method at runtime

guitar = Guitar()
piano = Piano()

perform(guitar)   # Output: Strumming the guitar... 
perform(piano)
# Out:
# Strumming the guitar...
# Playing the piano...

# %%
#Que7) Create a class MathOperations with a class method add_numbers() to add two numbers and a static method subtract_numbers() to subtract two numbers.
#Ans:-
class MathOperations:
    # Class method
    @classmethod
    def add_numbers(cls, a, b):
        return a + b

    # Static method
    @staticmethod
    def subtract_numbers(a, b):
        return a - b

# Calling class method
sum_result = MathOperations.add_numbers(10, 5)
print("Sum:", sum_result)  

# Calling static method
diff_result = MathOperations.subtract_numbers(10, 5)
print("Difference:", diff_result)
# Out:
# Sum: 15
# Difference: 5

# %%
#Que8) Implement a class Person with a class method to count the total number of persons created.
#Ans:-
class Person:
    # Class attribute to keep count
    count = 0

    def __init__(self, name):
        self.name = name
        Person.count += 1   # Increment count whenever a new Person is created

    # Class method to get total count
    @classmethod
    def total_persons(cls):
        return cls.count

p1 = Person("Alice")
p2 = Person("Bob")
p3 = Person("Charlie")

print("Total persons created:", Person.total_persons())
# Out:
# Total persons created: 3

# %%
#Que9) Write a class Fraction with attributes numerator and denominator. Override the str method to display the fraction as "numerator/denominator".
#Ans:-
class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    # Override the __str__ method
    def __str__(self):
        return f"{self.numerator}/{self.denominator}"

f1 = Fraction(3, 4)
f2 = Fraction(7, 2)

print(f1)  
print(f2)
# Out:
# 3/4
# 7/2

# %%
#Que10) Demonstrate operator overloading by creating a class Vector and overriding the add method to add two vectors.
#Ans:-
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    # Override the + operator
    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

    # For readable output
    def __str__(self):
        return f"({self.x}, {self.y})"

v1 = Vector(2, 3)
v2 = Vector(4, 5)

v3 = v1 + v2   # Uses the overloaded __add__ method
print("Resultant Vector:", v3)
# Out:
# Resultant Vector: (6, 8)

# %%
#Que11. Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is {name} and I am {age} years old."
#Ans:-
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

p1 = Person("Alice", 25)
p1.greet()   

p2 = Person("Bob", 30)
p2.greet()
# Out:
# Hello, my name is Alice and I am 25 years old.
# Hello, my name is Bob and I am 30 years old.

# %%
#Que12) Implement a class Student with attributes name and grades. Create a method average_grade() to compute the average of the grades.
#Ans:-
class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades  # Expecting a list of numbers

    def average_grade(self):
        if len(self.grades) == 0:
            return 0
        return sum(self.grades) / len(self.grades)

s1 = Student("Alice", [85, 90, 78])
s2 = Student("Bob", [70, 88, 92, 81])

print(f"{s1.name}'s average grade: {s1.average_grade():.2f}")  
print(f"{s2.name}'s average grade: {s2.average_grade():.2f}")
# Out:
# Alice's average grade: 84.33
# Bob's average grade: 82.75

# %%
#Que13) Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the area.
#Ans:-
class Rectangle:
    def __init__(self):
        self.length = 0
        self.width = 0

    # Method to set dimensions
    def set_dimensions(self, length, width):
        self.length = length
        self.width = width

    # Method to calculate area
    def area(self):
        return self.length * self.width

rect = Rectangle()
rect.set_dimensions(5, 3)   # Set length = 5, width = 3
print("Area of rectangle:", rect.area())
# Out:
# Area of rectangle: 15

# %%
#Que14) Create a class Employee with a method calculate_salary() that computes the salary based on hours worked and hourly rate. Create a derived class Manager that adds a bonus to the salary.
#Ans:-
# Base class
class Employee:
    def __init__(self, name, hours_worked, hourly_rate):
        self.name = name
        self.hours_worked = hours_worked
        self.hourly_rate = hourly_rate

    def calculate_salary(self):
        return self.hours_worked * self.hourly_rate

# Derived class
class Manager(Employee):
    def __init__(self, name, hours_worked, hourly_rate, bonus):
        super().__init__(name, hours_worked, hourly_rate)
        self.bonus = bonus

    # Override calculate_salary to include bonus
    def calculate_salary(self):
        base_salary = super().calculate_salary()
        return base_salary + self.bonus

emp = Employee("Alice", 40, 20)   
print(f"{emp.name}'s Salary: ${emp.calculate_salary()}")  

mgr = Manager("Bob", 40, 30, 500)  
print(f"{mgr.name}'s Salary: ${mgr.calculate_salary()}")
# Out:
# Alice's Salary: $800
# Bob's Salary: $1700

# %%
#Que15) Create a class Product with attributes name, price, and quantity. Implement a method total_price() that calculates the total price of the product.
#Ans:-
class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    # Method to calculate total price
    def total_price(self):
        return self.price * self.quantity

p1 = Product("Laptop", 800, 2)
p2 = Product("Phone", 500, 3)

print(f"Total price of {p1.name}: ${p1.total_price()}")  
print(f"Total price of {p2.name}: ${p2.total_price()}")
# Out:
# Total price of Laptop: $1600
# Total price of Phone: $1500

# %%
#Que16) Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that implement the sound() method.
#Ans:-
from abc import ABC, abstractmethod

# Abstract base class
class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass

# Derived class: Cow
class Cow(Animal):
    def sound(self):
        print("Moo!")

# Derived class: Sheep
class Sheep(Animal):
    def sound(self):
        print("Baa!")

cow = Cow()
sheep = Sheep()

cow.sound()  
sheep.sound()
# Out:
# Moo!
# Baa!

# %%
#Que17) Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that returns a formatted string with the book's details.
#Ans:-
class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    # Method to return book details
    def get_book_info(self):
        return f"'{self.title}' by {self.author}, published in {self.year_published}"

b1 = Book("To Kill a Mockingbird", "Harper Lee", 1960)
b2 = Book("1984", "George Orwell", 1949)

print(b1.get_book_info())  
print(b2.get_book_info())
# Out:
# 'To Kill a Mockingbird' by Harper Lee, published in 1960
# '1984' by George Orwell, published in 1949

# %%
#Que18) Create a class House with attributes address and price. Create a derived class Mansion that adds an attribute number_of_rooms.
#Ans:-
# Base class
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price

    def get_info(self):
        return f"House located at {self.address}, priced at ${self.price}"

# Derived class
class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms

    def get_info(self):
        return f"Mansion located at {self.address}, priced at ${self.price}, with {self.number_of_rooms} rooms"

house = House("123 Main Street", 250000)
print(house.get_info())

mansion = Mansion("456 Luxury Avenue", 2000000, 15)
print(mansion.get_info())
# Out:
# House located at 123 Main Street, priced at $250000
# Mansion located at 456 Luxury Avenue, priced at $2000000, with 15 rooms
